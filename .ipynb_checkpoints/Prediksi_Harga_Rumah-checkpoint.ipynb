# %% [markdown]
# <h1>Identitas</h1>
# <h4>Nama</h4>
# - BOBBY SUSANTO ALI 2440022504
# - KEVIN WIJAYA 2440020921
# - JALALUDIN AR RANIRY WILIAM TCHIN 2440066600
# <h4>Kelas</h4>
# - LA01
# <h4>AOL Project</h4>

# %%
import pandas as pd
import matplotlib.pyplot as mp

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report  

import seaborn as sb

import numpy as np

# %% [markdown]
# Read dataset yang pertama

# %%
df1 = pd.read_csv('data1.csv', sep = ';')
df1
# Out:
#         NO                                         NAMA RUMAH        HARGA  \
# 0        1  Rumah Murah Hook Tebet Timur, Tebet, Jakarta S...   3800000000
# 1        2  Rumah Modern di Tebet dekat Stasiun, Tebet, Ja...   4600000000
# 2        3  Rumah Mewah 2 Lantai Hanya 3 Menit Ke Tebet, T...   3000000000
# 3        4           Rumah Baru Tebet, Tebet, Jakarta Selatan    430000000
# 4        5  Rumah Bagus Tebet komp Gudang Peluru lt 350m, ...   9000000000
# ...    ...                                                ...          ...
# 1005  1006  Rumah Strategis Akses Jalan 2mobil Di Menteng ...   9000000000
# 1006  1007             Tebet Rumah Siap Huni Jln 2 Mbl Nyaman   4000000000
# 1007  1008        Di Kebun Baru Rumah Terawat, Area Strategis   4000000000
# 1008  1009  Dijual Cepat Rumah Komp Depkeu Dr Soepomo Tebe...  19000000000
# 1009  1010                Dijual Rumah Kokoh Di Gudang Peluru  10500000000
#
#        LB   LT  KT  KM  GRS
# 0     220  220   3   3    0
# ...

# %% [markdown]
# Mengekstrak variabel-variabel yang mungkin diperlukan

# %%
# df1_var = df1.loc[:,['LB', 'LT', 'KT', 'KM', 'GRS', 'HARGA']]
# df1_var

# %% [markdown]
# Tidak ada missing data

# %%
df1.isna().any().any()
# Out:
# False

# %% [markdown]
# Pada dataset yang kedua, hanya diberikan ada atau tidaknya garasi. Jika tidak ada garasi, dapat dipastikan banyaknya garasi adalah 0. Sedangkan jika disebutkan ada garasi, nilai garasi tersebut akan diisi dengan rata-rata dari banyaknya garasi di dataset pertama.

# %%
df1['GRS'].mean()
# Out:
# 1.9207920792079207

# %%
korelasi = df1.corr()
sb.heatmap(korelasi, 
            xticklabels = korelasi.columns,
            yticklabels = korelasi.columns,
            cmap = sb.diverging_palette(h_neg=250, h_pos=120, sep=3, as_cmap=True),
            vmin = -1,
            vmax = 1,
            annot = True
            )
# Out:
# <AxesSubplot:>

# %%
df2 = pd.read_csv('data2.csv', sep = ';')
df2
# Out:
#                HARGA    LT   LB  JKT  JKM        GRS    KOTA
# 0     28,000,000,000  1100  700    5    6        ADA  JAKSEL
# 1     19,000,000,000   824  800    4    4        ADA  JAKSEL
# 2      4,700,000,000   500  400    4    3        ADA  JAKSEL
# 3      4,900,000,000   251  300    5    4        ADA  JAKSEL
# 4     28,000,000,000  1340  575    4    5        ADA  JAKSEL
# ...              ...   ...  ...  ...  ...        ...     ...
# 996   16,000,000,000   488  550    6    5        ADA  JAKSEL
# 997    4,500,000,000   209  270    4    4        ADA  JAKSEL
# 998   29,000,000,000   692  400    4    3  TIDAK ADA  JAKSEL
# 999    1,700,000,000   102  140    4    3  TIDAK ADA  JAKSEL
# 1000   1,250,000,000    63  110    3    3  TIDAK ADA  JAKSEL
#
# [1001 rows x 7 columns]

# %%
df2.rename(columns = {'JKT':'KT', 'JKM':'KM'}, inplace = True)
df2
# Out:
#                HARGA    LT   LB  KT  KM        GRS    KOTA
# 0     28,000,000,000  1100  700   5   6        ADA  JAKSEL
# 1     19,000,000,000   824  800   4   4        ADA  JAKSEL
# 2      4,700,000,000   500  400   4   3        ADA  JAKSEL
# 3      4,900,000,000   251  300   5   4        ADA  JAKSEL
# 4     28,000,000,000  1340  575   4   5        ADA  JAKSEL
# ...              ...   ...  ...  ..  ..        ...     ...
# 996   16,000,000,000   488  550   6   5        ADA  JAKSEL
# 997    4,500,000,000   209  270   4   4        ADA  JAKSEL
# 998   29,000,000,000   692  400   4   3  TIDAK ADA  JAKSEL
# 999    1,700,000,000   102  140   4   3  TIDAK ADA  JAKSEL
# 1000   1,250,000,000    63  110   3   3  TIDAK ADA  JAKSEL
#
# [1001 rows x 7 columns]

# %%
df2['LT']
# Out:
# 0       1100
# 1        824
# 2        500
# 3        251
# 4       1340
#         ...
# 996      488
# 997      209
# 998      692
# 999      102
# 1000      63
# Name: LT, Length: 1001, dtype: int64

# %%
df1
# Out:
#         NO                                         NAMA RUMAH        HARGA  \
# 0        1  Rumah Murah Hook Tebet Timur, Tebet, Jakarta S...   3800000000
# 1        2  Rumah Modern di Tebet dekat Stasiun, Tebet, Ja...   4600000000
# 2        3  Rumah Mewah 2 Lantai Hanya 3 Menit Ke Tebet, T...   3000000000
# 3        4           Rumah Baru Tebet, Tebet, Jakarta Selatan    430000000
# 4        5  Rumah Bagus Tebet komp Gudang Peluru lt 350m, ...   9000000000
# ...    ...                                                ...          ...
# 1005  1006  Rumah Strategis Akses Jalan 2mobil Di Menteng ...   9000000000
# 1006  1007             Tebet Rumah Siap Huni Jln 2 Mbl Nyaman   4000000000
# 1007  1008        Di Kebun Baru Rumah Terawat, Area Strategis   4000000000
# 1008  1009  Dijual Cepat Rumah Komp Depkeu Dr Soepomo Tebe...  19000000000
# 1009  1010                Dijual Rumah Kokoh Di Gudang Peluru  10500000000
#
#        LB   LT  KT  KM  GRS
# 0     220  220   3   3    0
# ...

# %%
df = pd.DataFrame(columns = ['LT', 'LB', 'KT', 'KM', 'Harga'])
df
# Out:
# Empty DataFrame
# Columns: [LT, LB, KT, KM, Harga]
# Index: []

# %%
df['LT'] = df1['LT']
df['LT'].append(df2['LT'])
df
# Out:
#        LT   LB   KT   KM Harga
# 0     220  NaN  NaN  NaN   NaN
# 1     137  NaN  NaN  NaN   NaN
# 2     250  NaN  NaN  NaN   NaN
# 3      25  NaN  NaN  NaN   NaN
# 4     355  NaN  NaN  NaN   NaN
# ...   ...  ...  ...  ...   ...
# 1005  550  NaN  NaN  NaN   NaN
# 1006  140  NaN  NaN  NaN   NaN
# 1007  230  NaN  NaN  NaN   NaN
# 1008  606  NaN  NaN  NaN   NaN
# 1009  430  NaN  NaN  NaN   NaN
#
# [1010 rows x 5 columns]
